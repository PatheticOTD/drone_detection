# %% [markdown]
# # 🚁 AOD-4: YOLOv5n
#
# **ВКР — визуальный модуль: сравнение архитектур детекторов (таблица 5.10)**
#
# Датасет: **AOD-4** (22 516 img, 4 класса)
# Модель: **YOLOv5n** (~2.6 млн параметров) | epochs=80 | batch=16 | img=640
#
# Сплит фиксирован `SEED=42` — идентичен тетрадке YOLOv8n, поэтому метрики напрямую сравнимы.
#
#
# **Перед запуском:**
# - Add Data → `airborne-object-detection` (тот же датасет, что для YOLOv8n)
# - Settings → Accelerator: **GPU**, Internet: **On** (нужно для загрузки предобученных весов `yolov5nu.pt`)
# - **Resume при лимите 12 ч:** после первого запуска Save Version → в новом запуске Add Data из своего Output → тетрадка сама продолжит обучение с `last.pt`.

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 95.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %%
import os, json, yaml, shutil, random, time, warnings
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns, cv2
from collections import Counter
from IPython.display import Image as IPImage, display
import torch
from ultralytics import YOLO
warnings.filterwarnings('ignore')

DEVICE = 0 if torch.cuda.is_available() else 'cpu'
print(f'PyTorch {torch.__version__} | GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU"}')

SEED = 42
random.seed(SEED); np.random.seed(SEED)

WORK = Path('/kaggle/working')
VIZ = WORK / 'visualizations'
RUNS = WORK / 'runs'
for d in [VIZ, RUNS]: d.mkdir(parents=True, exist_ok=True)

MODEL_LABEL = 'YOLOv5n'
PRETRAINED  = 'yolov5nu.pt'
ModelClass  = YOLO
RUN_NAME    = 'yolov5n_aod4'
IMG_SIZE    = 640
BATCH       = 16
print('✅ Готово |', MODEL_LABEL)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PyTorch 2.10.0+cu128 | GPU: Tesla T4
# ✅ Готово | YOLOv5n

# %% [markdown]
# ---
# ## 1. Восстановление чекпоинтов (если есть)

# %%
# Ищем чекпоинты от предыдущих запусков в /kaggle/input
restored = False
for d in sorted(Path('/kaggle/input').iterdir()):
    if d.name == 'airborne-object-detection':
        continue  # это датасет, не чекпоинт
    weights = list(d.rglob('last.pt')) + list(d.rglob('best.pt'))
    if weights:
        print(f'📦 Найден предыдущий запуск: {d.name}')
        for w in weights:
            rel = w.relative_to(d)
            dst = RUNS / rel
            dst.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(w, dst)
            print(f'   ↻ скопирован {rel}')
        restored = True
        break

if not restored:
    print('🆕 Чекпоинтов нет — первый запуск')
# Out:
# 🆕 Чекпоинтов нет — первый запуск

# %% [markdown]
# ---
# ## 2. Подготовка датасета

# %%
SRC = Path('/kaggle/input/datasets/theyfearme/airbone-object-detection')
DS = WORK / 'dataset'

# Если уже подготовлен — пропускаем
if (DS / 'data.yaml').exists():
    print('✅ Датасет уже подготовлен')
else:
    assert (SRC / 'train' / 'images').exists(), f'Не найдено: {SRC}/train/images'
    print(f'📂 Источник: {SRC}')

    all_imgs = sorted((SRC/'train'/'images').glob('*.jpg'))
    all_imgs += sorted((SRC/'train'/'images').glob('*.png'))
    print(f'   Изображений: {len(all_imgs)}')

    random.shuffle(all_imgs)
    n = len(all_imgs)
    n_train = int(n * 0.80)
    n_val = int(n * 0.15)
    splits = {'train': all_imgs[:n_train],
              'valid': all_imgs[n_train:n_train+n_val],
              'test':  all_imgs[n_train+n_val:]}

    for sname, slist in splits.items():
        (DS/sname/'images').mkdir(parents=True, exist_ok=True)
        (DS/sname/'labels').mkdir(parents=True, exist_ok=True)
        for p in slist:
            shutil.copy2(p, DS/sname/'images'/p.name)
            lbl = SRC/'train'/'labels'/f'{p.stem}.txt'
            if lbl.exists(): shutil.copy2(lbl, DS/sname/'labels'/lbl.name)
        print(f'   {sname:5s}: {len(slist)}')

    # Читаем классы из оригинального yaml
    with open(SRC/'data.yaml') as f:
        orig = yaml.safe_load(f)
    names = orig.get('names', {0:'Bird',1:'Drone',2:'Helicopter',3:'Plane'})
    if isinstance(names, list): names = {i:n for i,n in enumerate(names)}
    nc = len(names)

    cfg = {'path':str(DS),'train':'train/images','val':'valid/images',
           'test':'test/images','names':names,'nc':nc}
    with open(DS/'data.yaml','w') as f: yaml.dump(cfg, f)
    print(f'\n✅ data.yaml создан ({nc} классов: {list(names.values())})')

YAML_PATH = DS / 'data.yaml'
with open(YAML_PATH) as f: ds_cfg = yaml.safe_load(f)
CLASS_NAMES = list(ds_cfg['names'].values()) if isinstance(ds_cfg['names'],dict) else ds_cfg['names']
NUM_CLASSES = len(CLASS_NAMES)
ds_root = DS
print(f'\n📋 Классы: {CLASS_NAMES}')
# Out:
# 📂 Источник: /kaggle/input/datasets/theyfearme/airbone-object-detection
#    Изображений: 22472
#    train: 17977
#    valid: 3370
#    test : 1125
#
# ✅ data.yaml создан (4 классов: ['airplane', 'bird', 'drone', 'helicopter'])
#
# 📋 Классы: ['airplane', 'bird', 'drone', 'helicopter']

# %%
os.listdir('/kaggle/input/datasets/theyfearme/airbone-object-detection')
# Out:
# ['README.roboflow.txt', 'data.yaml', 'train']

# %% [markdown]
# ---
# ## 3. EDA

# %%
# Подсчёт аннотаций
class_counts = Counter()
split_info = {}
for split in ['train','valid','test']:
    lbl_dir = ds_root/split/'labels'
    img_dir = ds_root/split/'images'
    if not img_dir.exists(): continue
    n_imgs = len(list(img_dir.iterdir()))
    for lf in lbl_dir.glob('*.txt'):
        for line in open(lf):
            parts = line.strip().split()
            if parts: class_counts[int(parts[0])] += 1
    split_info[split] = n_imgs
    print(f'   {split:5s}: {n_imgs} images')

print(f'\n📊 Классы:')
for i in sorted(class_counts): print(f'   [{i}] {CLASS_NAMES[i]:12s}: {class_counts[i]}')

# График
fig, ax = plt.subplots(figsize=(8,4))
names_plot = [CLASS_NAMES[i] for i in sorted(class_counts)]
vals = [class_counts[i] for i in sorted(class_counts)]
bars = ax.bar(names_plot, vals, color=['#2ecc71','#e74c3c','#3498db','#f39c12'][:len(names_plot)])
for b,v in zip(bars,vals): ax.text(b.get_x()+b.get_width()/2,v+50,str(v),ha='center',fontweight='bold')
ax.set_title('AOD-4: распределение классов'); ax.set_ylabel('Аннотаций'); ax.grid(axis='y',alpha=0.3)
plt.tight_layout(); plt.savefig(VIZ/'class_distribution.png',dpi=150,bbox_inches='tight'); plt.show()
# Out:
#    train: 17977 images
#    valid: 3370 images
#    test : 1125 images
#
# 📊 Классы:
#    [0] airplane    : 7900
#    [1] bird        : 7900
#    [2] drone       : 7900
#    [3] helicopter  : 7900

# %%
# Примеры с bbox
img_dir = ds_root/'train'/'images'
lbl_dir = ds_root/'train'/'labels'
all_imgs = [p for p in img_dir.iterdir() if p.suffix.lower() in {'.jpg','.png'}]
samples = random.sample(all_imgs, min(8, len(all_imgs)))

COLORS = [(0,200,0),(0,0,255),(255,165,0),(0,255,255)]
fig,axes = plt.subplots(2,4,figsize=(20,10)); axes=axes.flatten()
for ax,p in zip(axes,samples):
    img = cv2.cvtColor(cv2.imread(str(p)), cv2.COLOR_BGR2RGB)
    h,w = img.shape[:2]
    lf = lbl_dir/f'{p.stem}.txt'
    if lf.exists():
        for line in open(lf):
            parts = line.strip().split()
            if len(parts)>=5:
                ci=int(parts[0]); cx,cy,bw,bh=map(float,parts[1:5])
                x1,y1=int((cx-bw/2)*w),int((cy-bh/2)*h)
                x2,y2=int((cx+bw/2)*w),int((cy+bh/2)*h)
                c=COLORS[ci%len(COLORS)]
                cv2.rectangle(img,(x1,y1),(x2,y2),c,2)
                cv2.putText(img,CLASS_NAMES[ci],(x1,y1-5),cv2.FONT_HERSHEY_SIMPLEX,0.6,c,2)
    ax.imshow(img); ax.axis('off')
for j in range(len(samples),len(axes)): axes[j].axis('off')
plt.suptitle('AOD-4: примеры с разметкой',fontsize=14,fontweight='bold')
plt.tight_layout(); plt.savefig(VIZ/'sample_images.png',dpi=150,bbox_inches='tight'); plt.show()

# %% [markdown]
# ---
# ## 4. Обучение YOLOv5n

# %%
run_dir = RUNS / RUN_NAME
last_pt = run_dir / 'weights' / 'last.pt'
best_pt = run_dir / 'weights' / 'best.pt'

if last_pt.exists():
    print(f'🔄 Resume: {last_pt}')
    model = ModelClass(str(last_pt))
    extra = {'resume': True}
elif best_pt.exists():
    print(f'🔄 Fine-tune: {best_pt}')
    model = ModelClass(str(best_pt))
    extra = {}
else:
    print(f'🆕 Новое обучение с предобученных весов {PRETRAINED}')
    model = ModelClass(PRETRAINED)
    extra = {}

results = model.train(
    data=str(YAML_PATH),
    epochs=80,
    imgsz=IMG_SIZE,
    batch=BATCH,
    patience=15,
    device=DEVICE,
    workers=2,
    project=str(RUNS),
    name=RUN_NAME,
    exist_ok=True,
    optimizer='AdamW',
    lr0=0.001,
    mosaic=1.0,
    mixup=0.1,
    save=True,
    save_period=5,
    plots=True,
    verbose=True,
    **extra,
)
print('✅ Обучение завершено')
# Out:
# 🆕 Новое обучение с предобученных весов yolov5nu.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 100% ━━━━━━━━━━━━ 5.3MB 64.5MB/s 0.1s
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov5nu.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov5n_aod4, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/yolov5n_aod4, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  14                  -1  1      8320  ultralytics.nn.modules.conv.Conv             [128, 64, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     22912  ultralytics.nn.modules.block.C3              [128, 64, 1, False]
#  18                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1     74496  ultralytics.nn.modules.block.C3              [128, 128, 1, False]
#  21                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  24        [17, 20, 23]  1    752092  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# YOLOv5n summary: 154 layers, 2,509,244 parameters, 2,509,228 gradients, 7.2 GFLOPs
#
# Transferred 391/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 70.7MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2242.2±1472.1 MB/s, size: 432.6 KB)
# train: Scanning /kaggle/working/dataset/train/labels... 17977 images, 443 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 17977/17977 1.2Kit/s 15.1s
# train: New cache created: /kaggle/working/dataset/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2, len(boxes) = 25411. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 282.7±52.0 MB/s, size: 66.5 KB)
# val: Scanning /kaggle/working/dataset/valid/labels... 3370 images, 82 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3370/3370 1.2Kit/s 2.8s
# val: New cache created: /kaggle/working/dataset/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 4603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/yolov5n_aod4/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/yolov5n_aod4
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      2.03G      1.664      1.855      1.356          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.1s
#                    all       3370       4603       0.68      0.549      0.651      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80       2.6G      1.585      1.445      1.328          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 29.0s
#                    all       3370       4603      0.754      0.677      0.754      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80       2.6G      1.559      1.351      1.308          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.5s
#                    all       3370       4603      0.771      0.681      0.776      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80       2.6G      1.522      1.248      1.274          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.2it/s 4:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.1s
#                    all       3370       4603       0.83      0.729      0.825      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80       2.6G      1.489      1.189      1.256          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.3s
#                    all       3370       4603      0.861      0.778      0.864       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80       2.6G      1.462      1.114      1.239          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.3s
#                    all       3370       4603      0.858       0.82      0.879      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      2.61G      1.439       1.08      1.221          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.2it/s 4:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.7s
#                    all       3370       4603      0.862       0.82       0.89      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      2.61G      1.417      1.039      1.206          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 29.9s
#                    all       3370       4603      0.887      0.844      0.906      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      2.61G      1.412      1.028      1.209          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 29.9s
#                    all       3370       4603       0.89      0.844      0.909      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      2.61G      1.392     0.9786       1.19          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.2it/s 4:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.6it/s 29.6s
#                    all       3370       4603      0.903      0.857      0.922      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      2.61G      1.387     0.9666      1.185          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.9s
#                    all       3370       4603      0.907      0.872      0.928      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      2.61G      1.374     0.9571      1.182          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.2s
#                    all       3370       4603      0.903      0.874      0.925      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      2.61G      1.353     0.9278      1.175          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.8s
#                    all       3370       4603      0.911      0.881      0.934      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      2.61G      1.343     0.9135      1.166          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.9s
#                    all       3370       4603      0.911      0.888      0.936      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      2.61G      1.337     0.9088      1.164          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.0s
#                    all       3370       4603      0.921       0.87      0.935      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      2.61G      1.323     0.8854      1.158          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.5s
#                    all       3370       4603      0.918      0.886      0.941      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      2.61G      1.327     0.8841      1.157          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.921      0.892      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      2.61G      1.321     0.8658      1.153          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.5s
#                    all       3370       4603      0.932      0.896      0.946      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      2.61G      1.314     0.8623      1.152          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.6s
#                    all       3370       4603      0.931      0.905      0.949      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      2.61G      1.304     0.8432      1.149          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 3:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.6s
#                    all       3370       4603      0.932      0.907      0.951      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      2.61G        1.3      0.841      1.144          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 3:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.2s
#                    all       3370       4603      0.927      0.911      0.952      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      2.61G      1.293     0.8257      1.138          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.4s
#                    all       3370       4603      0.931      0.908      0.953      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      2.61G      1.293     0.8316      1.137          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.5s
#                    all       3370       4603      0.933      0.914      0.954      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      2.61G      1.278     0.8084      1.132          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 4:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.8s
#                    all       3370       4603       0.94      0.923       0.96      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      2.61G      1.273     0.8026       1.13          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 4:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.0s
#                    all       3370       4603      0.934      0.922      0.958      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      2.61G      1.268     0.7891      1.124          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 3:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.0s
#                    all       3370       4603      0.939      0.918      0.958      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      2.61G      1.272     0.7919      1.127          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.2s
#                    all       3370       4603      0.935      0.928       0.96      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      2.61G      1.271     0.7886      1.127          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 26.8s
#                    all       3370       4603      0.937      0.927       0.96      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      2.61G      1.254     0.7731      1.119          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.6s
#                    all       3370       4603      0.939      0.928       0.96      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      2.61G       1.25      0.768      1.118          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.7s
#                    all       3370       4603      0.939      0.927      0.961      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      2.61G      1.247      0.765      1.116          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.3s
#                    all       3370       4603       0.94      0.927      0.962      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      2.61G      1.243     0.7603      1.112          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.2s
#                    all       3370       4603      0.938       0.93      0.962      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      2.61G      1.237     0.7515      1.107          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.4s
#                    all       3370       4603      0.942      0.928      0.963      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      2.61G       1.23     0.7418      1.108          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.6s
#                    all       3370       4603      0.935      0.934      0.963      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      2.61G      1.232     0.7411      1.107          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.3s
#                    all       3370       4603      0.941      0.936      0.965      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      2.61G      1.216     0.7368      1.101          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.7s
#                    all       3370       4603      0.942       0.94      0.966      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      2.61G      1.225     0.7332      1.103          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.3s
#                    all       3370       4603      0.938      0.937      0.966      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      2.61G       1.22     0.7253      1.101          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.0s
#                    all       3370       4603      0.939      0.938      0.966      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      2.61G      1.208     0.7217      1.096          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.2s
#                    all       3370       4603      0.943      0.938      0.967       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      2.61G      1.205     0.7139      1.092          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.0s
#                    all       3370       4603      0.942      0.939      0.966       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      2.61G      1.199     0.7131      1.091          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.2s
#                    all       3370       4603      0.938      0.938      0.966       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      2.61G      1.197     0.7097      1.092          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.4s
#                    all       3370       4603      0.937      0.938      0.967      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      2.61G        1.2     0.7085      1.092          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.3s
#                    all       3370       4603      0.941      0.935      0.967      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      2.61G      1.195     0.7043      1.092          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.941      0.936      0.968      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      2.61G      1.195     0.6973      1.088          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.942      0.938      0.968      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      2.61G      1.193     0.6992       1.09          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.8s
#                    all       3370       4603      0.944      0.938      0.968      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      2.61G      1.188     0.6942      1.084          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.2s
#                    all       3370       4603      0.942      0.938      0.968      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      2.61G      1.184     0.6916      1.084          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.2s
#                    all       3370       4603      0.945      0.939      0.969      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      2.61G      1.179     0.6832       1.08          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.1s
#                    all       3370       4603      0.945      0.939      0.969      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      2.61G       1.17      0.673      1.078          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.3it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.6s
#                    all       3370       4603      0.944       0.94       0.97      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      2.61G      1.173     0.6772      1.079          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.4it/s 4:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.8s
#                    all       3370       4603      0.946      0.939      0.969      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      2.61G      1.163     0.6717      1.073          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.0s
#                    all       3370       4603      0.946       0.94       0.97      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      2.61G      1.168     0.6802      1.078          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 4.0it/s 26.8s
#                    all       3370       4603      0.947      0.939       0.97      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      2.61G      1.165     0.6647      1.075          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.946      0.939      0.969      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      2.61G      1.154     0.6618       1.07          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.5s
#                    all       3370       4603      0.947       0.94       0.97       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      2.61G      1.157     0.6568      1.073          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.947      0.939       0.97       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      2.61G       1.15     0.6594      1.068          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.1s
#                    all       3370       4603      0.947      0.939       0.97       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      2.61G      1.146     0.6532      1.068          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.8s
#                    all       3370       4603      0.947       0.94      0.969      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      2.61G      1.147     0.6487      1.065          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.6s
#                    all       3370       4603      0.947       0.94       0.97       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      2.61G      1.135     0.6433      1.063          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.4s
#                    all       3370       4603      0.948       0.94       0.97      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      2.61G      1.141     0.6437      1.064          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.8s
#                    all       3370       4603      0.947       0.94       0.97      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      2.61G      1.134     0.6354      1.064          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.6s
#                    all       3370       4603      0.948       0.94      0.971      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      2.61G      1.131     0.6373      1.062          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.5s
#                    all       3370       4603      0.948      0.941      0.971      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      2.61G      1.125     0.6312      1.058          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.949      0.942      0.971      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      2.61G       1.13     0.6365      1.059          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.7s
#                    all       3370       4603      0.948      0.941       0.97      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      2.61G      1.118     0.6266      1.055          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.5it/s 4:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.5s
#                    all       3370       4603      0.948      0.941       0.97      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      2.61G      1.124     0.6286      1.056          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.1s
#                    all       3370       4603      0.948      0.941       0.97      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      2.61G      1.116     0.6224      1.056          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 4:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 4.0it/s 26.8s
#                    all       3370       4603      0.949      0.941      0.971      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      2.61G      1.118     0.6238      1.057          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.6it/s 4:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.4s
#                    all       3370       4603      0.949      0.941      0.971      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      2.61G      1.116     0.6192      1.058          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 4:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.9it/s 27.1s
#                    all       3370       4603      0.949      0.941      0.971      0.673
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      2.61G      1.066     0.5162      1.022          9        640: 100% ━━━━━━━━━━━━ 1124/1124 5.0it/s 3:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 27.9s
#                    all       3370       4603      0.949       0.94       0.97      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      2.61G      1.052     0.5051      1.015          9        640: 100% ━━━━━━━━━━━━ 1124/1124 5.2it/s 3:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.7it/s 28.6s
#                    all       3370       4603      0.949      0.941       0.97      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      2.61G       1.05     0.5012      1.015          9        640: 100% ━━━━━━━━━━━━ 1124/1124 5.1it/s 3:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.8it/s 28.0s
#                    all       3370       4603      0.949      0.941      0.971      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      2.61G      1.042     0.4949       1.01          9        640: 100% ━━━━━━━━━━━━ 1124/1124 5.2it/s 3:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.6it/s 29.1s
#                    all       3370       4603      0.949      0.941      0.971      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      2.61G       1.04     0.4933      1.012          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.9it/s 3:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.3it/s 31.9s
#                    all       3370       4603       0.95      0.941       0.97      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      2.61G       1.03     0.4906      1.008          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 3:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.4it/s 31.1s
#                    all       3370       4603       0.95      0.941       0.97      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      2.61G      1.032     0.4884      1.007          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.7it/s 3:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.4it/s 31.2s
#                    all       3370       4603      0.949      0.941       0.97      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      2.61G      1.025     0.4839      1.004          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.9it/s 3:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.5s
#                    all       3370       4603      0.949      0.941       0.97      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      2.61G      1.025     0.4816      1.003          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.8it/s 3:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 29.9s
#                    all       3370       4603      0.949      0.941       0.97      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      2.61G      1.022     0.4798      1.002          9        640: 100% ━━━━━━━━━━━━ 1124/1124 4.8it/s 3:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.5it/s 30.5s
#                    all       3370       4603      0.949      0.941       0.97      0.674
#
# 80 epochs completed in 6.119 hours.
# Optimizer stripped from /kaggle/working/runs/yolov5n_aod4/weights/last.pt, 5.3MB
# Optimizer stripped from /kaggle/working/runs/yolov5n_aod4/weights/best.pt, 5.3MB
#
# Validating /kaggle/working/runs/yolov5n_aod4/weights/best.pt...
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv5n summary (fused): 85 layers, 2,503,724 parameters, 0 gradients, 7.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 106/106 3.1it/s 33.8s
#                    all       3370       4603      0.948      0.941       0.97      0.674
#               airplane        849       1175      0.937       0.93      0.966       0.71
#                   bird        498       1142      0.935       0.94      0.967      0.706
#                  drone       1089       1127      0.954      0.941      0.969      0.629
#             helicopter        857       1159      0.967      0.953       0.98      0.651
# Speed: 0.2ms preprocess, 1.7ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/yolov5n_aod4
# ✅ Обучение завершено

# %% [markdown]
# ---
# ## 5. Графики обучения

# %%
run_dir = RUNS / RUN_NAME
for plot in ['results.png','confusion_matrix.png','PR_curve.png','F1_curve.png']:
    p = run_dir / plot
    if p.exists():
        print(f'📊 {plot}:')
        display(IPImage(filename=str(p), width=800))
# Out:
# 📊 results.png:
# 📊 confusion_matrix.png:

# %% [markdown]
# ---
# ## 6. Оценка

# %%
best_pt = RUNS / RUN_NAME / 'weights' / 'best.pt'
if not best_pt.exists():
    print('⚠️ best.pt не найден')
else:
    model = ModelClass(str(best_pt))
    metrics = model.val(data=str(YAML_PATH), imgsz=IMG_SIZE, verbose=False)

    # FPS (среднее по 100 прогонам на «пустом» кадре)
    dummy = np.random.randint(0,255,(IMG_SIZE,IMG_SIZE,3),dtype=np.uint8)
    for _ in range(10): model.predict(dummy, verbose=False)
    ts = []
    for _ in range(100):
        t0=time.perf_counter(); model.predict(dummy,verbose=False); ts.append(time.perf_counter()-t0)
    fps = 1/np.mean(ts)

    params = sum(p.numel() for p in model.model.parameters())

    print(f'\n{"="*50}')
    print(f'📊 {MODEL_LABEL} — Результаты')
    print(f'{"="*50}')
    print(f'   mAP50:     {metrics.box.map50:.4f}')
    print(f'   mAP50-95:  {metrics.box.map:.4f}')
    print(f'   Precision: {metrics.box.mp:.4f}')
    print(f'   Recall:    {metrics.box.mr:.4f}')
    print(f'   FPS:       {fps:.1f}')
    print(f'   Params:    {params/1e6:.1f}M')

    result = {'Model':MODEL_LABEL,'mAP50':f'{metrics.box.map50:.4f}',
              'mAP50-95':f'{metrics.box.map:.4f}','Precision':f'{metrics.box.mp:.4f}',
              'Recall':f'{metrics.box.mr:.4f}','FPS':f'{fps:.1f}','Params(M)':f'{params/1e6:.1f}'}
    pd.DataFrame([result]).to_csv(VIZ/f'metrics_{RUN_NAME}.csv', index=False)
    print(f'\n💾 Метрики: {VIZ/f"metrics_{RUN_NAME}.csv"}')

    # Per-class AP50
    for i, name in enumerate(CLASS_NAMES):
        if i < len(metrics.box.ap50):
            print(f'   {name:12s}: AP50={metrics.box.ap50[i]:.4f}')
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv5n summary (fused): 85 layers, 2,503,724 parameters, 0 gradients, 7.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1043.0±1032.7 MB/s, size: 69.4 KB)
# val: Scanning /kaggle/working/dataset/valid/labels.cache... 3370 images, 82 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3370/3370 883.4Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 4603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 211/211 7.1it/s 29.7s
#                    all       3370       4603      0.949      0.941      0.971      0.675
# Speed: 0.7ms preprocess, 2.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#
# ==================================================
# 📊 YOLOv5n — Результаты
# ==================================================
#    mAP50:     0.9714
#    mAP50-95:  0.6748
#    Precision: 0.9493
#    Recall:    0.9413
#    FPS:       109.5
#    Params:    2.5M
#
# 💾 Метрики: /kaggle/working/visualizations/metrics_yolov5n_aod4.csv
#    airplane    : AP50=0.9678
#    bird        : AP50=0.9666
#    drone       : AP50=0.9707
#    helicopter  : AP50=0.9804

# %% [markdown]
# ---
# ## 7. Визуальный инференс

# %%
best_pt = RUNS / RUN_NAME / 'weights' / 'best.pt'
if best_pt.exists():
    model = ModelClass(str(best_pt))
    test_dir = ds_root / 'test' / 'images'
    if not test_dir.exists(): test_dir = ds_root / 'valid' / 'images'
    test_imgs = [p for p in test_dir.iterdir() if p.suffix.lower() in {'.jpg','.png'}]
    samples = random.sample(test_imgs, min(8, len(test_imgs)))

    fig,axes = plt.subplots(2,4,figsize=(20,10)); axes=axes.flatten()
    for ax,p in zip(axes,samples):
        res = model.predict(str(p), imgsz=IMG_SIZE, conf=0.25, verbose=False)
        ann = cv2.cvtColor(res[0].plot(), cv2.COLOR_BGR2RGB)
        ax.imshow(ann); ax.set_title(f'{len(res[0].boxes)} obj',fontsize=10); ax.axis('off')
    for j in range(len(samples),len(axes)): axes[j].axis('off')
    plt.suptitle(f'{MODEL_LABEL} — детекция',fontsize=15,fontweight='bold')
    plt.tight_layout(); plt.savefig(VIZ/'detection_results.png',dpi=150,bbox_inches='tight'); plt.show()

# %% [markdown]
# ---
# ## 8. Сводка

# %%
print(f'\n📥 Артефакты ({MODEL_LABEL}):')
for p,d in [(RUNS/RUN_NAME/'weights/best.pt','Best weights'),
            (RUNS/RUN_NAME/'weights/last.pt','Last checkpoint'),
            (RUNS/RUN_NAME/'results.png','Training curves'),
            (RUNS/RUN_NAME/'confusion_matrix.png','Confusion matrix'),
            (VIZ/f'metrics_{RUN_NAME}.csv','Metrics CSV'),
            (VIZ/'detection_results.png','Detection results')]:
    p=Path(p)
    if p.exists(): print(f'  ✅ {d:25s} — {p.name} ({p.stat().st_size/1e6:.1f} MB)')
    else: print(f'  ⬜ {d}')
print(f'\n   💡 Для resume: Save Version → New Dataset из Output → Add Data при новом запуске')
print(f'   📋 Перенесите строку из metrics_{RUN_NAME}.csv в таблицу 5.10 ВКР')
# Out:
# 📥 Артефакты (YOLOv5n):
#   ✅ Best weights              — best.pt (5.3 MB)
#   ✅ Last checkpoint           — last.pt (5.3 MB)
#   ✅ Training curves           — results.png (0.2 MB)
#   ✅ Confusion matrix          — confusion_matrix.png (0.1 MB)
#   ✅ Metrics CSV               — metrics_yolov5n_aod4.csv (0.0 MB)
#   ✅ Detection results         — detection_results.png (1.3 MB)
#
#    💡 Для resume: Save Version → New Dataset из Output → Add Data при новом запуске
#    📋 Перенесите строку из metrics_yolov5n_aod4.csv в таблицу 5.10 ВКР
